# %%
from abc import abstractmethod


class car():
    def __init__(self,*args, **kwargs):
        pass

@abstractmethod
def start(self):
    start = "started car with auto injestion"
    return start

def stop(self):
        pass

def model(self):
        pass

def engine(self):
        pass

def color(self):
        pass

def year(self):
        pass


car_obj = car("Toyota", "Corolla", 2020, "Blue", "Gasoline")
start_car = start(True)
print(f"Car started is {start_car}.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 31
#      27         pass
#      28
#      29
#      30 car_obj = car("Toyota", "Corolla", 2020, "Blue", "Gasoline")
# ---> 31 start_car = start(True)
#      32 print(f"Car started is {start_car}.")
#
# Cell In[5], line 10, in start(self)
#       8 @abstractmethod
#       9 def start(self):
# ---> 10         start = self.boolean
#      11         print(f"Car started {start}.")
#      12         pass
#
# AttributeError: 'bool' object has no attribute 'boolean'
